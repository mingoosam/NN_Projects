# %%
from keras.datasets import mnist
from keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
(train_X, train_Y), (test_x, test_y) = mnist.load_data()
(train_Xf, train_Yf), (test_xf, test_yf) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(train_X.shape) # train images (X, Y) -> images, labels for training
print(train_Y.shape) # train labels
print(test_x.shape) # test images (x, y) -> images, labels for testing
print(test_y.shape) # test labels
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(train_X[0])

# %%
print(train_Y[0])
# Out:
# 5

# %%
plt.imshow(test_x[0])

# %%
print(test_y[0])
# Out:
# 7

# %% [markdown]
# ## Labels for Fashion MNIST
#
# ![Screenshot%202023-01-29%20at%204.06.26%20PM.png](attachment:Screenshot%202023-01-29%20at%204.06.26%20PM.png)

# %%
print(train_Xf.shape) # train images (X, Y) -> images, labels for training
print(train_Yf.shape) # train labels
print(test_xf.shape) # test images (x, y) -> images, labels for testing
print(test_yf.shape) # test labels
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(train_Xf[0])

# %%
print(train_Yf[0]) # 9 is ankle boot
# Out:
# 9

# %%
plt.imshow(test_xf[1]) # 2 is pullover

# %%
print(test_yf[1])
# Out:
# 2
